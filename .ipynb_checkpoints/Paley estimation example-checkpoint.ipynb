# %% [markdown]
# In this document we&rsquo;ll work through a simple approach to estimating
# Constant Frisch Elasticity (CFE) demand systems.
#
# There are two prerequisites; the first is the `CFEDemands` python
# module, which can be installed with a simple:

# %%
pip install --upgrade pip command
# Out:
# Requirement already up-to-date: pip in /srv/app/venv/lib/python3.6/site-packages (20.0.2)
# Requirement already up-to-date: command in /srv/app/venv/lib/python3.6/site-packages (0.1.0)
# Requirement already satisfied, skipping upgrade: setuptools in /srv/app/venv/lib/python3.6/site-packages (from command) (46.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install CFEDemands --pre
# Out:
# Requirement already satisfied: CFEDemands in /srv/app/venv/lib/python3.6/site-packages (0.2.1.dev0)

# %% [markdown]
# The second prerequisite is a dataset including detailed information on
# household expenditures and characteristics.  The structure of that
# dataset is detailed in the next section.

# %% [markdown]
# ## Data

# %% [markdown]
# Consider the case in which the data are saved in a google sheet; we&rsquo;ll
# turn data from these into `pandas` dataframes.
# There are limits on the allowable size of google sheets (5 million
# cells), so if your dataset is larger than this you&rsquo;ll need some other
# mechanism to get your data into such dataframes.  Even in this latter
# case you&rsquo;ll want your dataframes to have a structure that matches the
# description given below.

# %% [markdown]
# ### Structure of the Spreadsheet

# %% [markdown]
# An example spreadsheet can be found at
# [https://docs.google.com/spreadsheets/d/13Ig5hZif-NSHtgkKRp_cEgKXk0lOsdUB2BAD6O_FnRo/](https://docs.google.com/spreadsheets/d/13Ig5hZif-NSHtgkKRp_cEgKXk0lOsdUB2BAD6O_FnRo/).
#
# This spreadsheet consists of two worksheets, labeled &ldquo;Expenditures&rdquo;
# and &ldquo;Household Characteristics&rdquo;, respectively.
#
# Each worksheet has the initial three columns labeled &ldquo;j&rdquo;, &ldquo;t&rdquo;, and
# &ldquo;m&rdquo;; together these identify an observation uniquely.  The column &ldquo;j&rdquo;
# should include a household id; the column &ldquo;t&rdquo; should include an
# indicator for the year or period (for those of you with
# cross-sectional data these will all take a common value, e.g., 2019);
# the column &ldquo;m&rdquo; should be an indicator of &ldquo;market&rdquo;, which may be a
# region identifier, or may take a single value (e.g., &ldquo;Malawi&rdquo;).
#
# The triple (j,t,m) will serve as the index of some constructed
# dataframes.  It is important not to have **too** many different values
# for &ldquo;m&rdquo; (unless you have lots of RAM to play with).
#
# Beyond the first three columns, the &ldquo;Expenditures&rdquo; worksheet should
# have one column for each category of expenditures (e.g., &ldquo;Rice&rdquo;, &ldquo;Goat
# meat&rdquo;, &ldquo;Millet&rdquo;,&#x2026;).
#
# Beyond the first three columns, the &ldquo;Household Characteristics&rdquo; should
# have columns corresponding to different elements of the vector of
# observable characteristics $z$.  If the data allow, I recommend
# constructing observables that match what I have in the ICRISAT data:
# namely numbers of &ldquo;Men&rdquo;, &ldquo;Women&rdquo;, &ldquo;Boys&rdquo; and &ldquo;Girls&rdquo;; also the
# logarithm of total household size (&ldquo;log HSize&rdquo;).

# %% [markdown]
# ### From Sheet to DataFrame to Result Object

# %% [markdown]
# We begin by defining a dictionary that contains the spreadsheet key.
# One is provided for the Indian ICRISAT example that I wish to work
# through.

# %% [markdown]
# With the spreadsheet defined , grab it and define a couple of
# dataframes. Note that the spreadsheet must be public for this approach
# to work!

# %%
Sheets = {'MALAWI':'1I4x4y_FDWGkPMZcKANmsSBbKbOlLFC61sE-5DT9OgY4'    
}

# %%
import pandas as pd
import numpy as np

# The function below adapted from Gianmario Spacagna's suggestion at
# https://stackoverflow.com/questions/19611729/getting-google-spreadsheet-csv-into-a-pandas-dataframe
def dataframe_from_gspreadsheet(sheet_name, key):
    """Transform public google spreadsheet into pandas.DataFrame."""
    
    url = 'https://docs.google.com/spreadsheets/d/{key}/gviz/tq?tqx=out:csv&sheet={sheet_name}&headers=1'.format(
        key=key, sheet_name=sheet_name.replace(' ', '%20'))

    df = pd.read_csv(url)

    return df.drop([col for col in df.columns if col.startswith('Unnamed')], axis=1)

# Change 'ICRISAT' to key of your own sheet in Sheets, above
x = dataframe_from_gspreadsheet("Expenditures", Sheets['MALAWI'])

# Change 'ICRISAT' to key of your own sheet in Sheets, above
z = dataframe_from_gspreadsheet("HH Characteristics", Sheets['MALAWI'])

# Assume a single market: (Comment this out to make each village its own market)
z['m'] = 1
x['m'] = 1

# Take logs of expenditures; call this y
y = np.log(x.replace(0,np.nan).set_index(['j','t','m']))

z.set_index(['j','t','m'],inplace=True)

# %% [markdown]
# This gives a dataframe of household characteristics $z$ with a simple structure.

# %%
z.head()
# Out:
#                     Girls  Boys  Women  Men
# j           t    m
# 10101002025 2004 1      3     3      1    1
# 10101002051 2004 1      0     0      1    1
# 10101002072 2004 1      3     3      1    1
# 10101002079 2004 1      1     1      1    1
# 10101002095 2004 1      2     2      1    1

# %% [markdown]
# Also a dataframe of log expenditures $y$ with a similarly simple
# structure.  Note that any expenditures of zero are dropped and
# replaced with a missing value indicator.

# %%
y.head()
# Out:
#                     Apple   Avocado    Banana  Bean, brown  Bean, white  \
# j           t    m
# 10101002025 2004 1    NaN  2.302585       NaN          NaN          NaN
# 10101002051 2004 1    NaN       NaN       NaN          NaN          NaN
# 10101002072 2004 1    NaN  1.609438  1.609438          NaN          NaN
# 10101002079 2004 1    NaN  2.772589  4.094345          NaN          NaN
# 10101002095 2004 1    NaN       NaN       NaN          NaN          NaN
#
#                         Beef  Biscuits  Bottled/ canned beer  Bread  \
# j           t    m
# 10101002025 2004 1  5.075174       NaN                   NaN    NaN
# 10101002051 2004 1       NaN       NaN                   NaN    NaN
# 10101002072 2004 1       NaN       NaN                   NaN    NaN
# 10101002079 2004 1  4.094345       NaN                   NaN    NaN
# 10101002095 2004 1       NaN       NaN                   NaN    NaN
#
#                     Breakfast cereal ...   Traditional beer (masase)  \
# j           t    m                   ...
# 10101002025 2004 1               NaN ...                         NaN
# 10101002051 2004 1               NaN ...                         NaN
# 10101002072 2004 1               NaN ...                         NaN
# 10101002079 2004 1               NaN ...                         NaN
# 10101002095 2004 1               NaN ...                         NaN
#
#                     Traditional beer (masese)  Wheat flour  \
# j           t    m
# 10101002025 2004 1                        NaN          NaN
# 10101002051 2004 1                        NaN          NaN
# 10101002072 2004 1                        NaN          NaN
# 10101002079 2004 1                        NaN          NaN
# 10101002095 2004 1                        NaN          NaN
#
#                     White sweet potato  Wild fruit (masau, malambe, etc.)  \
# j           t    m
# 10101002025 2004 1                 NaN                                NaN
# 10101002051 2004 1                 NaN                                NaN
# 10101002072 2004 1                 NaN                                NaN
# 10101002079 2004 1                 NaN                                NaN
# 10101002095 2004 1                 NaN                                NaN
#
#                     Wild fruit (masau, mlambe, etc.)  \
# j           t    m
# 10101002025 2004 1                               NaN
# 10101002051 2004 1                               NaN
# 10101002072 2004 1                               NaN
# 10101002079 2004 1                               NaN
# 10101002095 2004 1                               NaN
#
#                     Wine or commercial liquor  \
# j           t    m
# 10101002025 2004 1                        NaN
# 10101002051 2004 1                        NaN
# 10101002072 2004 1                        NaN
# 10101002079 2004 1                        NaN
# 10101002095 2004 1                        NaN
#
#                     Yeast, baking powder, bicarbonate of soda  Yoghurt  nan
# j           t    m
# 10101002025 2004 1                                   1.386294      NaN  NaN
# 10101002051 2004 1                                        NaN      NaN  NaN
# 10101002072 2004 1                                   1.098612      NaN  NaN
# 10101002079 2004 1                                   0.693147      NaN  NaN
# 10101002095 2004 1                                   1.098612      NaN  NaN
#
# [5 rows x 160 columns]

# %% [markdown]
# ## Estimation

# %% [markdown]
# With nothing more than this, we can estimate the demand system.  This
# happens in two steps.  The first is the &ldquo;reduced form&rdquo; step:

# %%
import cfe

result = cfe.Result(y=y.head(),z=z.head())

# %% [markdown]
# This creates a complicated &ldquo;Result&rdquo; object, with lots of different
# attributes.  Note from below that attributes $y$ and $z$ are now defined.

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0ac921c19f1a> in <module>
# ----> 1 result
#
# NameError: name 'result' is not defined

# %% [markdown]
# ### First step of Estimation

# %% [markdown]
# Recall that there are two steps to estimation; the first step
# involves estimating the &ldquo;reduced form&rdquo; linear regression
# $$
# y_{it}^j = {a}_{it} + \delta_i'{z}^j_t + \epsilon_{it}^j.
# $$
#
# The Result class has code to estimate this in one line:

# %%
result.get_reduced_form()

# %% [markdown]
# After running this we can examine the estimated coefficients $\delta$:

# %%
result.delta.to_dataframe().unstack('k')
# Out:
#                                                        delta            \
# k                                                      F 0-3   F 14-18
# i
# Barber service (and material relating to it)       -0.155298  0.069883
# Bengalgram dhal                                    -0.351645 -0.018770
# Brinjal                                            -0.137576  0.050528
# Ceremonial expenses                                -0.140808  0.282122
# Chillies                                           -0.074296  0.001783
# Clothing                                           -0.163853 -0.062719
# Coconut                                            -0.234838  0.058048
# Complete meals in hotel                             0.240410 -0.090966
# Cosmetics tooth paste etc.                         -0.205726  0.055812
# Edible oils                                         0.050772 -0.018103
# Educational material expenses (pen, books, pape...  0.210978  0.149959
# Ghee                                               -0.358507 -0.303368
# Grinding/milling charges                           -0.094573 -0.007706
# Groundnuts                                         -0.352390 -0.012557
# Gur (jaggery)                                       0.027076  0.073120
# Jowar/Sorghum (HYV)                                 0.108568 -0.018231
# Jowar/Sorghum (Local variety)                      -0.310349 -0.032083
# Medicine Doctor's fees                              0.046243 -0.023007
# Milk                                               -0.099425 -0.052953
# Onion                                              -0.003150 -0.103355
# Other dhal                                         -0.313536  0.066354
# Other spices                                       -0.116720 -0.027050
# Other sugar products                                0.063878 -0.053445
# Other vegetables                                   -0.026503 -0.116802
# Pan, betel, etc.                                    0.002070  0.072269
# Processed foods (e.g. biscuits Khara, syrup, ba... -0.023874 -0.220040
# Redgram dhal                                       -0.293705 -0.084976
# Rice (local variety)                               -0.025194 -0.080766
# Soap, washing powder                               -0.053425  0.045728
# Sugar                                              -0.319545 -0.101454
# Tea                                                 0.143878  0.012398
# Tobacco, beedi                                      0.002503 -0.026428
# Tomato                                             -0.302385 -0.018111
# Travel & Entertainment                             -0.167644  0.063042
# Utilities                                          -0.006988  0.031880
# Wheat (HYV)                                         0.345518  0.170980
#
#                                                                         \
# k                                                    F 19-30   F 31-50
# i
# Barber service (and material relating to it)       -0.068227  0.096067
# Bengalgram dhal                                     0.144831  0.292641
# Brinjal                                             0.059101  0.027299
# Ceremonial expenses                                -0.004657  0.132529
# Chillies                                            0.062246  0.240842
# Clothing                                            0.083455  0.314037
# Coconut                                             0.184028  0.202727
# Complete meals in hotel                             0.295855  0.225875
# Cosmetics tooth paste etc.                          0.239585  0.273921
# Edible oils                                         0.082781  0.209394
# Educational material expenses (pen, books, pape...  0.207006  0.388022
# Ghee                                                0.039563 -0.052337
# Grinding/milling charges                            0.031842  0.242291
# Groundnuts                                          0.048450  0.104583
# Gur (jaggery)                                       0.373573  0.592071
# Jowar/Sorghum (HYV)                                 0.072330  0.138291
# Jowar/Sorghum (Local variety)                       0.051744  0.309061
# Medicine Doctor's fees                              0.182913  0.194472
# Milk                                               -0.012051 -0.150906
# Onion                                               0.069692  0.023508
# Other dhal                                          0.143443  0.396490
# Other spices                                        0.116272  0.151684
# Other sugar products                                0.006471 -0.049822
# Other vegetables                                    0.141445  0.298796
# Pan, betel, etc.                                    0.197859  0.274666
# Processed foods (e.g. biscuits Khara, syrup, ba... -0.040420  0.042501
# Redgram dhal                                        0.158967  0.195286
# Rice (local variety)                                0.045105 -0.067301
# Soap, washing powder                                0.156264 -0.003527
# Sugar                                               0.178306  0.198718
# Tea                                                 0.297323  0.208831
# Tobacco, beedi                                     -0.029335  0.060643
# Tomato                                              0.254791 -0.083917
# Travel & Entertainment                              0.207211  0.149088
# Utilities                                           0.037684  0.279779
# Wheat (HYV)                                         0.136253  0.089320
#
#                                                                         \
# k                                                      F 4-8     F 51+
# i
# Barber service (and material relating to it)        0.070161  0.097520
# Bengalgram dhal                                     0.009864  0.136575
# Brinjal                                            -0.010082  0.043164
# Ceremonial expenses                                -0.181718  0.314220
# Chillies                                            0.035401  0.139133
# Clothing                                           -0.034111  0.025607
# Coconut                                            -0.031928  0.022955
# Complete meals in hotel                             0.110185  0.168455
# Cosmetics tooth paste etc.                         -0.029956  0.068004
# Edible oils                                         0.022512  0.186079
# Educational material expenses (pen, books, pape... -0.046311  0.558763
# Ghee                                               -0.244253 -0.072222
# Grinding/milling charges                           -0.017233  0.051484
# Groundnuts                                          0.056756  0.160228
# Gur (jaggery)                                       0.132227  0.281773
# Jowar/Sorghum (HYV)                                 0.085080 -0.040677
# Jowar/Sorghum (Local variety)                      -0.131242  0.137625
# Medicine Doctor's fees                              0.004748  0.079118
# Milk                                               -0.203789 -0.127849
# Onion                                              -0.096968 -0.015655
# Other dhal                                          0.178298 -0.100544
# Other spices                                        0.000392  0.083227
# Other sugar products                                0.026910  0.097815
# Other vegetables                                    0.022415  0.123194
# Pan, betel, etc.                                    0.120739  0.195610
# Processed foods (e.g. biscuits Khara, syrup, ba... -0.030149 -0.060275
# Redgram dhal                                       -0.037092  0.169166
# Rice (local variety)                               -0.158201 -0.095786
# Soap, washing powder                               -0.059445  0.013180
# Sugar                                              -0.171444  0.072353
# Tea                                                 0.012609  0.293591
# Tobacco, beedi                                     -0.077224 -0.187701
# Tomato                                              0.024957 -0.265647
# Travel & Entertainment                             -0.175116  0.023578
# Utilities                                          -0.072210  0.107860
# Wheat (HYV)                                         0.099181  0.268483
#
#                                                                         \
# k                                                     F 9-13     M 0-3
# i
# Barber service (and material relating to it)       -0.030266 -0.112102
# Bengalgram dhal                                    -0.116471 -0.164578
# Brinjal                                            -0.038551 -0.137549
# Ceremonial expenses                                 0.071340 -0.039662
# Chillies                                           -0.116553 -0.143800
# Clothing                                            0.028325 -0.181269
# Coconut                                            -0.138078 -0.204837
# Complete meals in hotel                             0.285044  0.017824
# Cosmetics tooth paste etc.                          0.060363 -0.094830
# Edible oils                                         0.050308  0.045751
# Educational material expenses (pen, books, pape...  0.374935 -0.070862
# Ghee                                               -0.109456 -0.140118
# Grinding/milling charges                            0.027985 -0.149040
# Groundnuts                                          0.005085 -0.679003
# Gur (jaggery)                                       0.117561 -0.145043
# Jowar/Sorghum (HYV)                                 0.183105  0.078404
# Jowar/Sorghum (Local variety)                      -0.230071 -0.422133
# Medicine Doctor's fees                              0.093177  0.047457
# Milk                                               -0.001023 -0.143051
# Onion                                              -0.013687 -0.051597
# Other dhal                                         -0.058251 -0.020444
# Other spices                                       -0.087419 -0.122751
# Other sugar products                                0.058516  0.035676
# Other vegetables                                   -0.035189 -0.188105
# Pan, betel, etc.                                    0.099938 -0.070429
# Processed foods (e.g. biscuits Khara, syrup, ba... -0.232849 -0.120095
# Redgram dhal                                        0.073943 -0.005678
# Rice (local variety)                                0.006167  0.028538
# Soap, washing powder                                0.063529  0.042195
# Sugar                                               0.019174 -0.126659
# Tea                                                 0.158883 -0.121027
# Tobacco, beedi                                     -0.162890 -0.034205
# Tomato                                              0.018554 -0.053905
# Travel & Entertainment                              0.081101 -0.076657
# Utilities                                          -0.006454  0.078596
# Wheat (HYV)                                         0.253490  0.237201
#
#                                                                         \
# k                                                    M 14-18   M 19-30
# i
# Barber service (and material relating to it)        0.166005  0.080497
# Bengalgram dhal                                     0.026348  0.034697
# Brinjal                                             0.002820  0.063449
# Ceremonial expenses                                 0.088339  0.067513
# Chillies                                            0.021543  0.077345
# Clothing                                            0.006907  0.047275
# Coconut                                             0.105740 -0.023508
# Complete meals in hotel                             0.039424 -0.058242
# Cosmetics tooth paste etc.                         -0.027429 -0.056823
# Edible oils                                         0.090523  0.235204
# Educational material expenses (pen, books, pape...  0.497133  0.022379
# Ghee                                                0.091821  0.167035
# Grinding/milling charges                            0.003964  0.089838
# Groundnuts                                          0.003346 -0.070966
# Gur (jaggery)                                       0.001152  0.182834
# Jowar/Sorghum (HYV)                                -0.100778  0.108521
# Jowar/Sorghum (Local variety)                      -0.050277 -0.036366
# Medicine Doctor's fees                              0.051784 -0.086738
# Milk                                                0.100715  0.000241
# Onion                                               0.006014 -0.036071
# Other dhal                                         -0.140973  0.057884
# Other spices                                        0.040719  0.037321
# Other sugar products                                0.141527 -0.126364
# Other vegetables                                   -0.099454  0.077151
# Pan, betel, etc.                                    0.039883  0.127491
# Processed foods (e.g. biscuits Khara, syrup, ba... -0.110583 -0.127141
# Redgram dhal                                        0.127186  0.206413
# Rice (local variety)                                0.025005  0.158544
# Soap, washing powder                                0.109947  0.026772
# Sugar                                              -0.017132  0.035164
# Tea                                                 0.012804  0.060668
# Tobacco, beedi                                     -0.053027 -0.098825
# Tomato                                             -0.004758  0.019844
# Travel & Entertainment                              0.008817  0.132524
# Utilities                                           0.056686  0.040893
# Wheat (HYV)                                         0.281790  0.351716
#
#                                                                         \
# k                                                    M 31-50     M 4-8
# i
# Barber service (and material relating to it)        0.359567 -0.054713
# Bengalgram dhal                                     0.359094 -0.238428
# Brinjal                                             0.255449 -0.128207
# Ceremonial expenses                                 0.381698 -0.232102
# Chillies                                            0.175819 -0.074879
# Clothing                                            0.192335 -0.144484
# Coconut                                             0.255671 -0.038666
# Complete meals in hotel                             0.093744  0.215039
# Cosmetics tooth paste etc.                          0.266875 -0.148297
# Edible oils                                         0.282227  0.007535
# Educational material expenses (pen, books, pape...  0.264470  0.044372
# Ghee                                                0.080429 -0.103353
# Grinding/milling charges                            0.214631 -0.105173
# Groundnuts                                          0.292578 -0.188555
# Gur (jaggery)                                       0.503367 -0.181353
# Jowar/Sorghum (HYV)                                 0.271771  0.025414
# Jowar/Sorghum (Local variety)                       0.405084 -0.261618
# Medicine Doctor's fees                              0.260556 -0.052907
# Milk                                                0.284268 -0.013618
# Onion                                              -0.113095 -0.124853
# Other dhal                                          0.065371  0.088851
# Other spices                                        0.118420 -0.062052
# Other sugar products                                0.174714 -0.040465
# Other vegetables                                    0.179085 -0.247395
# Pan, betel, etc.                                    0.532073 -0.121016
# Processed foods (e.g. biscuits Khara, syrup, ba...  0.275820 -0.251519
# Redgram dhal                                        0.322916 -0.176104
# Rice (local variety)                               -0.002518 -0.106039
# Soap, washing powder                                0.278301 -0.034561
# Sugar                                               0.366398 -0.149309
# Tea                                                 0.388932 -0.106991
# Tobacco, beedi                                      0.044403 -0.059653
# Tomato                                             -0.326515  0.075471
# Travel & Entertainment                              0.324309 -0.140793
# Utilities                                           0.168305 -0.044446
# Wheat (HYV)                                         0.499268  0.179532
#
#                                                                         \
# k                                                      M 51+    M 9-13
# i
# Barber service (and material relating to it)        0.287742  0.096345
# Bengalgram dhal                                     0.048459 -0.141448
# Brinjal                                             0.019635 -0.067321
# Ceremonial expenses                                 0.115794 -0.111190
# Chillies                                            0.091677 -0.073948
# Clothing                                           -0.042092 -0.051302
# Coconut                                             0.165565 -0.087931
# Complete meals in hotel                             0.360962  0.189173
# Cosmetics tooth paste etc.                          0.115923 -0.097094
# Edible oils                                         0.028620 -0.034573
# Educational material expenses (pen, books, pape...  0.091972  0.339408
# Ghee                                               -0.029333 -0.028972
# Grinding/milling charges                            0.131461 -0.031587
# Groundnuts                                          0.552803 -0.073134
# Gur (jaggery)                                       0.041312 -0.145115
# Jowar/Sorghum (HYV)                                 0.036526  0.066858
# Jowar/Sorghum (Local variety)                       0.171792 -0.171452
# Medicine Doctor's fees                              0.326375 -0.225465
# Milk                                                0.204066 -0.099116
# Onion                                              -0.015956 -0.038917
# Other dhal                                          0.474844 -0.171885
# Other spices                                        0.143404  0.001964
# Other sugar products                                0.235893  0.238772
# Other vegetables                                   -0.057889 -0.093932
# Pan, betel, etc.                                    0.243198 -0.054347
# Processed foods (e.g. biscuits Khara, syrup, ba...  0.029482 -0.121582
# Redgram dhal                                        0.067412 -0.098308
# Rice (local variety)                                0.120495  0.100348
# Soap, washing powder                                0.362105  0.097313
# Sugar                                               0.136799 -0.078968
# Tea                                                 0.090372  0.012350
# Tobacco, beedi                                      0.148937 -0.235480
# Tomato                                              0.193918  0.220323
# Travel & Entertainment                              0.092197 -0.094278
# Utilities                                           0.120558 -0.053004
# Wheat (HYV)                                        -0.186624  0.077193
#
#
# k                                                  log Hsize
# i
# Barber service (and material relating to it)        0.746865
# Bengalgram dhal                                     0.731850
# Brinjal                                             0.645154
# Ceremonial expenses                                 0.881516
# Chillies                                            0.492881
# Clothing                                            0.979769
# Coconut                                             0.366894
# Complete meals in hotel                            -0.597440
# Cosmetics tooth paste etc.                          0.662619
# Edible oils                                         0.137572
# Educational material expenses (pen, books, pape... -0.483651
# Ghee                                                1.114184
# Grinding/milling charges                            0.640912
# Groundnuts                                          0.668979
# Gur (jaggery)                                      -0.024955
# Jowar/Sorghum (HYV)                                 0.109786
# Jowar/Sorghum (Local variety)                       1.143384
# Medicine Doctor's fees                              0.639769
# Milk                                                0.940263
# Onion                                               0.604425
# Other dhal                                         -0.098313
# Other spices                                        0.396800
# Other sugar products                                0.432039
# Other vegetables                                    0.635062
# Pan, betel, etc.                                    0.197730
# Processed foods (e.g. biscuits Khara, syrup, ba...  1.169130
# Redgram dhal                                        0.326820
# Rice (local variety)                                0.360234
# Soap, washing powder                                0.393363
# Sugar                                               0.855681
# Tea                                                -0.044293
# Tobacco, beedi                                      0.482783
# Tomato                                              0.034496
# Travel & Entertainment                              0.536606
# Utilities                                           0.246988
# Wheat (HYV)                                        -0.453536

# %% [markdown]
# Also the good-time constants $a_{it}$:

# %%
result.a.to_dataframe().unstack('i')
# Out:
#                                                 a                            \
# i    Barber service (and material relating to it) Bengalgram dhal   Brinjal
# t  m
# 75 1                                     1.639606        2.211314 -0.647588
# 76 1                                     0.527107        1.257281  0.440981
# 77 1                                     0.338447        1.624714  0.358145
# 78 1                                     0.362211        1.712362  0.252359
# 79 1                                     0.381325        1.963829  0.543881
# 80 1                                     0.409766        1.965053  0.949557
# 81 1                                     0.899481        1.796022  1.292350
# 82 1                                     0.536633        1.768787  0.544825
# 83 1                                    -2.014022        1.692287 -1.117433
# 84 1                                          NaN             NaN       NaN
#
#                                                         \
# i    Ceremonial expenses  Chillies  Clothing   Coconut
# t  m
# 75 1            2.015941  2.504149  2.808436  0.024896
# 76 1            1.532861  3.109310  3.539089  0.052982
# 77 1            0.580013  2.988572  3.508620  0.582652
# 78 1            0.986107  2.840087  3.426051  0.618594
# 79 1            1.196748  3.219860  3.435293  1.137889
# 80 1            1.273603  3.260600  3.780804  1.111884
# 81 1            0.584513  3.515536  3.883632  1.430204
# 82 1            0.328785  2.908384  3.413429  1.290482
# 83 1            2.379180  0.448104  3.262924  1.557921
# 84 1                 NaN       NaN       NaN       NaN
#
#                                                                      \
# i    Complete meals in hotel Cosmetics tooth paste etc. Edible oils
# t  m
# 75 1                1.739906                   0.816662    2.618672
# 76 1                2.055805                   1.326507    3.203524
# 77 1                2.366018                   1.514680    3.534650
# 78 1                2.930517                   1.424382    3.190261
# 79 1                2.084027                   1.675132    3.864440
# 80 1                2.104684                   1.783004    4.135122
# 81 1                3.315428                   2.026163    3.825737
# 82 1                3.312780                   1.472446    3.786849
# 83 1                4.194982                  -1.104029    1.326281
# 84 1                     NaN                        NaN         NaN
#
#          ...                                                             \
# i        ...     Redgram dhal Rice (local variety) Soap, washing powder
# t  m     ...
# 75 1     ...         3.026875             2.972779             0.294528
# 76 1     ...         1.618166             1.900983             0.659113
# 77 1     ...         2.749476             2.574779             0.915852
# 78 1     ...         1.957461             2.661999             1.035408
# 79 1     ...         2.509986             2.926459             1.455115
# 80 1     ...         2.673328             3.370759             1.463322
# 81 1     ...         2.636365             3.722601             1.459143
# 82 1     ...         2.451816             3.551195             1.220578
# 83 1     ...         4.662835             4.224447             0.584687
# 84 1     ...              NaN                  NaN                  NaN
#
#                                                                           \
# i        Sugar       Tea Tobacco, beedi    Tomato Travel & Entertainment
# t  m
# 75 1  0.959657  2.040962       1.957728 -0.715497               2.061131
# 76 1  1.316965  2.544336       2.884421  0.450645               3.130017
# 77 1  1.635037  2.708342       3.072858  0.852500               2.965746
# 78 1  1.953014  2.793329       3.087737  0.900109               3.178562
# 79 1  2.097439  2.916330       3.267793  1.772735               2.893743
# 80 1  2.271587  2.978549       3.307476  1.480273               3.102639
# 81 1  2.161658  2.940125       3.154688  1.889618               3.355532
# 82 1  1.635239  2.447381       2.683196  1.715393               3.017816
# 83 1  0.691763  1.392019       1.268193  0.321111               0.609738
# 84 1       NaN       NaN            NaN       NaN                    NaN
#
#
# i    Utilities Wheat (HYV)
# t  m
# 75 1  2.154264    3.706282
# 76 1  2.924236    2.791892
# 77 1  3.003145    4.161031
# 78 1  2.772677    3.923782
# 79 1  3.241533    4.393744
# 80 1  3.299897    3.186594
# 81 1  3.201498    3.387369
# 82 1  2.569561    3.872649
# 83 1 -0.778068    5.325763
# 84 1       NaN         NaN
#
# [10 rows x 36 columns]

# %% [markdown]
# ### Second step of Estimation

# %% [markdown]
# The second step involves using Singular Value Decomposition to find
# the rank one matrix that best approximates the residuals $e_{it}^j$.
# This can be interpreted as
# $$
#     -\beta_i\log\lambda^j_t,
# $$
# where the $\log\lambda^j_t$ is the log of the marginal utility of
# expenditures (MUE) for household $j$ at time $t$, and where $\beta_i$ are
# the corresponding &ldquo;Frisch elasticities&rdquo; that tell us how much
# demand changes as the MUE falls.
#
# Estimates can also be computed as a one-liner:

# %%
result.get_beta().to_dataframe()
# Out:
#                                                         beta
# i
# Barber service (and material relating to it)        0.150678
# Bengalgram dhal                                     0.729380
# Brinjal                                             0.397938
# Ceremonial expenses                                 1.112815
# Chillies                                            0.326102
# Clothing                                            0.578654
# Coconut                                             0.219991
# Complete meals in hotel                             0.120233
# Cosmetics tooth paste etc.                          0.642459
# Edible oils                                         0.704342
# Educational material expenses (pen, books, pape...  0.216423
# Ghee                                                0.326095
# Grinding/milling charges                            0.314791
# Groundnuts                                          0.025760
# Gur (jaggery)                                       1.364810
# Jowar/Sorghum (HYV)                                 0.572147
# Jowar/Sorghum (Local variety)                       0.327026
# Medicine Doctor's fees                              0.644373
# Milk                                                0.494768
# Onion                                               0.185969
# Other dhal                                          0.003214
# Other spices                                        0.296798
# Other sugar products                                0.275217
# Other vegetables                                    0.787170
# Pan, betel, etc.                                    1.032955
# Processed foods (e.g. biscuits Khara, syrup, ba...  0.323792
# Redgram dhal                                        0.933793
# Rice (local variety)                                0.279338
# Soap, washing powder                                0.526305
# Sugar                                               0.702594
# Tea                                                 0.552818
# Tobacco, beedi                                      0.053430
# Tomato                                             -0.476183
# Travel & Entertainment                              0.695591
# Utilities                                           0.383186
# Wheat (HYV)                                         1.075910

# %% [markdown]
# That&rsquo;s all there is to estimation!  Note that we didn&rsquo;t estimate
# demands for all goods&#x2014;lots of goods didn&rsquo;t have enough observations,
# and were automatically dropped.  (This can be controlled using the
# `min_proportion_items` and `min_xproducts` attributes when one
# instantiates the result object.)

# %% [markdown]
# ### Assessment of Fit

# %% [markdown]
# Now, let&rsquo;s see how we did, by comparing total expenditures predicted by the
# model we&rsquo;ve estimated with actual total expenditures:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.cm as cm

xbar = np.exp(result.y).sum(['m','i']).to_dataframe('xbar').replace(0,np.nan).squeeze()
xhat = result.get_predicted_expenditures().sum(['m','i']).to_dataframe('xhat').replace(0,np.nan).squeeze()

# Make dataframe of actual & predicted
df = pd.DataFrame({'Actual':np.log(xbar),'Predicted':np.log(xhat)})

df.plot.scatter(x='Predicted',y='Actual')

# Add 45 degree line
v = plt.axis()
vmin = np.max([v[0],v[2]])
vmax = np.max([v[1],v[3]])
plt.plot([vmin,vmax],[vmin,vmax])
# Out:
# /srv/app/venv/lib/python3.6/site-packages/xarray/core/nanops.py:160: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# /srv/app/venv/lib/python3.6/site-packages/xarray/core/nputils.py:220: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)
